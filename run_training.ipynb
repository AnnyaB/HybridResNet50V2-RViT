# %%
import os
os.getcwd()
# Out:
# '/Users/riyabasak_15/brain_tumor_project'

# %%
import os

IN_COLAB = os.path.exists("/content")

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content/drive/MyDrive/FYP/brain_tumor_project
else:
    # %cd "/Users/riyabasak_15/brain_tumor_project"

# !ls
# Out:
# /Users/riyabasak_15/brain_tumor_project
# README.md          docs               requirements.txt   scripts
# data               explainability     results
# dataset_prep.ipynb models             run_training.ipynb
